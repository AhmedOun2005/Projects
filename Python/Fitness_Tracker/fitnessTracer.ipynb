# %% [markdown]
# ## Analysis For Fitness trackers 🏃‍➡️🏃‍♂️‍➡️🏊‍♀️🚴‍♂️🏋️🕒

# %%
import pandas as pd
df = pd.read_csv("Fitness_trackers.csv")
df
# Out:
#     Brand Name  Device Type             Model Name             Color  \
# 0       Xiaomi  FitnessBand           Smart Band 5             Black
# 1       Xiaomi  FitnessBand           Smart Band 4             Black
# 2       Xiaomi  FitnessBand               HMSH01GE             Black
# 3       Xiaomi  FitnessBand           Smart Band 5             Black
# 4       Xiaomi  FitnessBand                 Band 3             Black
# ..         ...          ...                    ...               ...
# 560     Huawei   Smartwatch            Watch 36456             Black
# 561     Huawei   Smartwatch  GT Fortuna-B19S Sport             Black
# 562      GOQii  FitnessBand                     HR             Black
# 563      GOQii  FitnessBand                  Vital             Black
# 564    FOSSIL    Smartwatch                 Gen 5E  Grey, Multicolor
#
#     Selling Price Original Price         Display  Rating (Out of 5)  \
# 0           2,499          2,999  AMOLED Display                4.1
# ...

# %%
df['Reviews'].isnull().sum()
# Out:
# np.int64(487)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 11 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Brand Name                      565 non-null    object
#  1   Device Type                     565 non-null    object
#  2   Model Name                      565 non-null    object
#  3   Color                           565 non-null    object
#  4   Selling Price                   565 non-null    object
#  5   Original Price                  565 non-null    object
#  6   Display                         565 non-null    object
#  7   Rating (Out of 5)               514 non-null    float64
#  8   Strap Material                  565 non-null    object
#  9   Average Battery Life (in days)  565 non-null    int64
#  10  Reviews                         78 non-null     object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 48.7+ KB

# %%
df.shape
# Out:
# (565, 11)

# %% [markdown]
# ### Drop Null Values

# %%
df.drop('Reviews',axis='columns',inplace=True)
df
# Out:
#     Brand Name  Device Type             Model Name             Color  \
# 0       Xiaomi  FitnessBand           Smart Band 5             Black
# 1       Xiaomi  FitnessBand           Smart Band 4             Black
# 2       Xiaomi  FitnessBand               HMSH01GE             Black
# 3       Xiaomi  FitnessBand           Smart Band 5             Black
# 4       Xiaomi  FitnessBand                 Band 3             Black
# ..         ...          ...                    ...               ...
# 560     Huawei   Smartwatch            Watch 36456             Black
# 561     Huawei   Smartwatch  GT Fortuna-B19S Sport             Black
# 562      GOQii  FitnessBand                     HR             Black
# 563      GOQii  FitnessBand                  Vital             Black
# 564    FOSSIL    Smartwatch                 Gen 5E  Grey, Multicolor
#
#     Selling Price Original Price         Display  Rating (Out of 5)  \
# 0           2,499          2,999  AMOLED Display                4.1
# ...

# %%
df.isnull().sum()
# Out:
# Brand Name                         0
# Device Type                        0
# Model Name                         0
# Color                              0
# Selling Price                      0
# Original Price                     0
# Display                            0
# Rating (Out of 5)                 51
# Strap Material                     0
# Average Battery Life (in days)     0
# dtype: int64

# %%
df['Rating (Out of 5)']=df['Rating (Out of 5)'].fillna(df['Rating (Out of 5)'].median())
df.isnull().sum()
# Out:
# Brand Name                        0
# Device Type                       0
# Model Name                        0
# Color                             0
# Selling Price                     0
# Original Price                    0
# Display                           0
# Rating (Out of 5)                 0
# Strap Material                    0
# Average Battery Life (in days)    0
# dtype: int64

# %% [markdown]
# ### change Datatype for Prices

# %%
df['Selling Price']=df['Selling Price'].str.replace(',','')
df['Original Price']=df['Original Price'].str.replace(',','')
df['Selling Price']=df['Selling Price'].astype(float)
df['Original Price']=df['Original Price'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 565 entries, 0 to 564
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Brand Name                      565 non-null    object
#  1   Device Type                     565 non-null    object
#  2   Model Name                      565 non-null    object
#  3   Color                           565 non-null    object
#  4   Selling Price                   565 non-null    float64
#  5   Original Price                  565 non-null    float64
#  6   Display                         565 non-null    object
#  7   Rating (Out of 5)               565 non-null    float64
#  8   Strap Material                  565 non-null    object
#  9   Average Battery Life (in days)  565 non-null    int64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 44.3+ KB

# %% [markdown]
# ### Drop Duplicated Values

# %%
df.duplicated().sum()
# Out:
# np.int64(4)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Transforming some Error values in Color

# %%
df['Color']=df['Color'].str.replace(' ','')
df['Color']=df['Color'].str.title()
df['Color']=df['Color'].str.replace('Grey','Gray')

# %%
df
# Out:
#     Brand Name  Device Type             Model Name            Color  \
# 0       Xiaomi  FitnessBand           Smart Band 5            Black
# 1       Xiaomi  FitnessBand           Smart Band 4            Black
# 2       Xiaomi  FitnessBand               HMSH01GE            Black
# 3       Xiaomi  FitnessBand           Smart Band 5            Black
# 4       Xiaomi  FitnessBand                 Band 3            Black
# ..         ...          ...                    ...              ...
# 560     Huawei   Smartwatch            Watch 36456            Black
# 561     Huawei   Smartwatch  GT Fortuna-B19S Sport            Black
# 562      GOQii  FitnessBand                     HR            Black
# 563      GOQii  FitnessBand                  Vital            Black
# 564    FOSSIL    Smartwatch                 Gen 5E  Gray,Multicolor
#
#      Selling Price  Original Price         Display  Rating (Out of 5)  \
# 0           2499.0          2999.0  AMOLED Display                4.1
# ...

# %%
df.groupby('Color').agg({'Color':'count'})
# Out:
#                                  Color
# Color
# Beige                                5
# Black                              201
# Black,Beige                          1
# Black,Blue                           4
# Black,Blue,Pink                      2
# ...                                ...
# Violet,Black,Gray,Teal,Blue,Red      1
# White                               22
# White,Black                          2
# White,Pink                           1
# Yellow                               3
#
# [131 rows x 1 columns]

# %%
df['Color']=df['Color'].apply(lambda x : str(sorted(str(x).split(','))))

# %%
df.groupby('Color').agg({'Color':'count'})
# Out:
#                                                Color
# Color
# ['Beige', 'Black', 'Pink']                         1
# ['Beige', 'Black']                                 1
# ['Beige']                                          5
# ['Beigegold', 'Charcoalblack']                     1
# ['Black', 'Blue', 'Deepwine', 'Gray', 'Teal']      1
# ...                                              ...
# ['Stone']                                          1
# ['Tidalblue']                                      1
# ['Violet']                                         1
# ['White']                                         22
# ['Yellow']                                         3
#
# [118 rows x 1 columns]

# %%
df
# Out:
#     Brand Name  Device Type             Model Name                   Color  \
# 0       Xiaomi  FitnessBand           Smart Band 5               ['Black']
# 1       Xiaomi  FitnessBand           Smart Band 4               ['Black']
# 2       Xiaomi  FitnessBand               HMSH01GE               ['Black']
# 3       Xiaomi  FitnessBand           Smart Band 5               ['Black']
# 4       Xiaomi  FitnessBand                 Band 3               ['Black']
# ..         ...          ...                    ...                     ...
# 560     Huawei   Smartwatch            Watch 36456               ['Black']
# 561     Huawei   Smartwatch  GT Fortuna-B19S Sport               ['Black']
# 562      GOQii  FitnessBand                     HR               ['Black']
# 563      GOQii  FitnessBand                  Vital               ['Black']
# 564    FOSSIL    Smartwatch                 Gen 5E  ['Gray', 'Multicolor']
#
# ...

# %% [markdown]
# ### Add column for Discount

# %%
df['Discount']=df['Original Price']-df['Selling Price']
df
# Out:
#     Brand Name  Device Type             Model Name                   Color  \
# 0       Xiaomi  FitnessBand           Smart Band 5               ['Black']
# 1       Xiaomi  FitnessBand           Smart Band 4               ['Black']
# 2       Xiaomi  FitnessBand               HMSH01GE               ['Black']
# 3       Xiaomi  FitnessBand           Smart Band 5               ['Black']
# 4       Xiaomi  FitnessBand                 Band 3               ['Black']
# ..         ...          ...                    ...                     ...
# 560     Huawei   Smartwatch            Watch 36456               ['Black']
# 561     Huawei   Smartwatch  GT Fortuna-B19S Sport               ['Black']
# 562      GOQii  FitnessBand                     HR               ['Black']
# 563      GOQii  FitnessBand                  Vital               ['Black']
# 564    FOSSIL    Smartwatch                 Gen 5E  ['Gray', 'Multicolor']
#
# ...

# %% [markdown]
# ### Deep understanding all data fo analysis and Business Questions

# %%
df.groupby(['Brand Name']).agg({'Brand Name':'count'})
# Out:
#             Brand Name
# Brand Name
# APPLE               84
# FOSSIL             133
# Fastrack             6
# FitBit              50
# GARMIN             100
# GOQii                4
# Honor               20
# Huawei              26
# Infinix              1
# LAVA                 1
# LCARE                2
# Noise                2
# Noise               17
# OnePlus              3
# Oppo                 2
# SAMSUNG             48
# Xiaomi              10
# boAt                 4
# huami               36
# realme              12

# %%
df.groupby(['Device Type']).agg({'Device Type':'count'})
# Out:
#              Device Type
# Device Type
# FitnessBand           75
# Smartwatch           486

# %%
df.groupby(['Model Name']).agg({'Model Name':'count'})
# Out:
#                                                     Model Name
# Model Name
# 2 - 42 mm Silver Aluminium Case                              1
# 2 Pro                                                        1
# 2S                                                           1
# 38 mm Space Black Stainless Steel Case                       1
# 38 mm Stainless Steel Stainless Steel Case with...           1
# ...                                                        ...
# Z1                                                           1
# band 4 running                                               1
# series 2 - 38 mm Stainless Steel Case                        1
# versa                                                        1
# vivoactive 4S 40mm                                           1
#
# [384 rows x 1 columns]

# %%
df.groupby(['Display']).agg({'Display':'count'})
# Out:
#                      Display
# Display
# AMOLED Display           353
# LCD Display               20
# LED Display               28
# OLED Display              43
# OLED Retina Display       84
# PMOLED Display            20
# TFT-LCD Display           13

# %%
df.groupby(['Strap Material']).agg({'Strap Material':'count'})
# Out:
#                             Strap Material
# Strap Material
# Aluminium                               55
# Elastomer                               44
# Fabric                                   1
# Leather                                 59
# Leather                                  1
# Nylon                                   12
# Plastic                                 16
# Rubber                                  11
# Silicone                               231
# Stainless Steel                         97
# Thermoplastic polyurethane              33
# leather                                  1

# %%
df.groupby(['Color']).agg({'Color':'count'})
# Out:
#                                                Color
# Color
# ['Beige', 'Black', 'Pink']                         1
# ['Beige', 'Black']                                 1
# ['Beige']                                          5
# ['Beigegold', 'Charcoalblack']                     1
# ['Black', 'Blue', 'Deepwine', 'Gray', 'Teal']      1
# ...                                              ...
# ['Stone']                                          1
# ['Tidalblue']                                      1
# ['Violet']                                         1
# ['White']                                         22
# ['Yellow']                                         3
#
# [118 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
# plt.figure(figsize=(10,20))
import seaborn as sns
sns.countplot(y=df['Brand Name'],hue=df['Device Type'],order=df['Brand Name'].value_counts()[:10].index,color='skyblue')
plt.grid(True)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18332\500841619.py:4: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:skyblue'` for the same effect.
#
#   sns.countplot(y=df['Brand Name'],hue=df['Device Type'],order=df['Brand Name'].value_counts()[:10].index,color='skyblue')

# %%
sns.countplot
# Out:
# <function seaborn.categorical.countplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, fill=True, hue_norm=None, stat='count', width=0.8, dodge='auto', gap=0, log_scale=None, native_scale=False, formatter=None, legend='auto', ax=None, **kwargs)>

# %%
col=df['Color'].value_counts()[:10]
plt.figure(figsize=(10,5))
plt.bar(col.index,col.values)
# Out:
# <BarContainer object of 10 artists>

# %%
df.columns
# Out:
# Index(['Brand Name', 'Device Type', 'Model Name', 'Color', 'Selling Price',
#        'Original Price', 'Display', 'Rating (Out of 5)', 'Strap Material',
#        'Average Battery Life (in days)', 'Discount'],
#       dtype='object')

# %%
plt.figure(figsize=(20,5))
sns.stripplot(x=df['Rating (Out of 5)'],y=df['Selling Price'])
# Out:
# <Axes: xlabel='Rating (Out of 5)', ylabel='Selling Price'>

# %%
x=df.groupby(['Brand Name']).agg({'Rating (Out of 5)':'mean'})
plt.figure(figsize=(20,5))
# plt.plot(x,y,label='Squire',linestyle='--',color='red',marker='o')
plt.plot(x.index,x['Rating (Out of 5)'],linestyle='--',color='red',marker='o')

# %%
import numpy as np
Display_Selling=df.groupby(['Display']).agg({'Selling Price':'mean'})
Display_Selling['Selling Price']=Display_Selling['Selling Price'].astype('int')
Display_Selling
# Out:
#                      Selling Price
# Display
# AMOLED Display               17596
# LCD Display                  13056
# LED Display                  23065
# OLED Display                 20863
# OLED Retina Display          49523
# PMOLED Display                7983
# TFT-LCD Display               2260

# %%
plt.pie(Display_Selling['Selling Price'],labels=Display_Selling.index,autopct='%1.1f%%',explode=(.05,.06,.05,.05,.09,.05,.05),shadow=True)
plt.show()

# %%
sns.set_style("white")
sns.pairplot(df,hue='Brand Name',height=3)
